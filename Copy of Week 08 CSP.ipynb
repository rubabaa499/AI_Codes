# %%
# Define a new cgraph
cgraph = {'WA': ['SA', 'NT'], 
          'Q': ['SA', 'NT', 'NSW'], 
          'T': [],
          'V': ['SA', 'NSW'], 
          'SA': ['WA', 'NT', 'Q', 'NSW','V'], 
          'NT': ['Q', 'WA', 'SA'], 
          'NSW': ['Q', 'V', 'SA']}

# %%
import random
def get_color(node, rv, cg):
    # CODE
    # check rv[node] is empty or not when no color availabe
    # return 'no color'
    color = random.choice(rv[node])
    rv.pop(node)
    # update remaining values for neihbouring node
    adjList = cg[node]
    for adj in adjList:
        if adj in rv.keys() and color in rv[adj]:
            rv[adj].remove(color)
            if len(rv[adj]) == 0:
              return "no color"
    #print(adjList)
    return color

# %% [markdown]
# ## Highest Degree Node

# %%
# write a method to get the highest degree node
def get_hdnode(cg, solved):
    mnode = ''
    degree = -1
    for k in cg.keys():
        if len(cg[k])  > degree and k not in solved.keys():
            #print(k)
            degree = len(cg[k])
            mnode = k
    return mnode

# %%
get_hdnode(cgraph, {'SA':'R'})
# Out:
# 'Q'

# %% [markdown]
# Color the nodes using Highest degree heuristic

# %%
assigned = {} # store assigned variables with colors
remainingValues = {'WA': ['R','G','B'], 
                    'Q': ['R','G','B'],
                    'T': ['R','G','B'],
                    'V':  ['R','G','B'], 
                    'NT': ['R','G','B'],
                    'SA': ['R','G','B'],                    
                    'NSW': ['R','G','B']}

for i in range(len(cgraph)):
    print('rv: ', end="")
    print(remainingValues)
    # assign color to the highest degree node
    hdNode = get_hdnode(cgraph, assigned)
    print('Selected Node: '+hdNode)
    color = get_color(hdNode, remainingValues, cgraph)
    # CODE
    if color == "no color":
      print("FAILURE")
      break
    # check if 'no color' is returned
    # print failure

    assigned[hdNode]= color
    print('assigned: ', end="")
    print(assigned)
# Out:
# rv: {'WA': ['R', 'G', 'B'], 'Q': ['R', 'G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'NT': ['R', 'G', 'B'], 'SA': ['R', 'G', 'B'], 'NSW': ['R', 'G', 'B']}
# Selected Node: SA
# assigned: {'SA': 'G'}
# rv: {'WA': ['R', 'B'], 'Q': ['R', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'B'], 'NT': ['R', 'B'], 'NSW': ['R', 'B']}
# Selected Node: Q
# assigned: {'SA': 'G', 'Q': 'B'}
# rv: {'WA': ['R', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'B'], 'NT': ['R'], 'NSW': ['R']}
# Selected Node: NT
# assigned: {'SA': 'G', 'Q': 'B', 'NT': 'R'}
# rv: {'WA': ['B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'B'], 'NSW': ['R']}
# Selected Node: NSW
# assigned: {'SA': 'G', 'Q': 'B', 'NT': 'R', 'NSW': 'R'}
# rv: {'WA': ['B'], 'T': ['R', 'G', 'B'], 'V': ['B']}
# Selected Node: WA
# assigned: {'SA': 'G', 'Q': 'B', 'NT': 'R', 'NSW': 'R', 'WA': 'B'}
# rv: {'T': ['R', 'G', 'B'], 'V': ['B']}
# Selected Node: V
# assigned: {'SA': 'G', 'Q': 'B', 'NT': 'R', 'NSW': 'R', 'WA': 'B', 'V': 'B'}
# rv: {'T': ['R', 'G', 'B']}
# Selected Node: T
# assigned: {'SA': 'G', 'Q': 'B', 'NT': 'R', 'NSW': 'R', 'WA': 'B', 'V': 'B', 'T': 'G'}

# %% [markdown]
# ## Minimum Remaining Value

# %%
# define a method to select a node by MRV
def get_MRVnode(rv):
    
    mnode = ''
    degree = 5
    for k in rv.keys():
        if len(rv[k])  < degree :
            #print(k)
            degree = len(rv[k])
            node = k
    return node

# %% [markdown]
# Color the nodes using MRV heuristic

# %%
assigned = {}

remainingValues = {'WA': ['R','G','B'], 
                    'Q': ['R','G','B'],
                    'T': ['R','G','B'],
                    'V':  ['R','G','B'], 
                    'NT': ['R','G','B'],
                    'SA': ['R','G','B'],                    
                    'NSW': ['R','G','B']}

for i in range(len(cgraph)):
    # assign color to the highest degree node
    rv = mv = []
    print(remainingValues)    
    mrvNode = get_MRVnode(remainingValues)
    color = get_color(mrvNode, remainingValues, cgraph)
    # CODE
    if color == "no color":
      print("FAILURE")
      break
    # check if 'no color' is returned
    # print failure

    assigned[mrvNode]= color
    print(assigned)
# Out:
# {'WA': ['R', 'G', 'B'], 'Q': ['R', 'G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'NT': ['R', 'G', 'B'], 'SA': ['R', 'G', 'B'], 'NSW': ['R', 'G', 'B']}
# {'WA': 'R'}
# {'Q': ['R', 'G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'NT': ['G', 'B'], 'SA': ['G', 'B'], 'NSW': ['R', 'G', 'B']}
# {'WA': 'R', 'NT': 'B'}
# {'Q': ['R', 'G'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'SA': ['G'], 'NSW': ['R', 'G', 'B']}
# {'WA': 'R', 'NT': 'B', 'SA': 'G'}
# {'Q': ['R'], 'T': ['R', 'G', 'B'], 'V': ['R', 'B'], 'NSW': ['R', 'B']}
# {'WA': 'R', 'NT': 'B', 'SA': 'G', 'Q': 'R'}
# {'T': ['R', 'G', 'B'], 'V': ['R', 'B'], 'NSW': ['B']}
# {'WA': 'R', 'NT': 'B', 'SA': 'G', 'Q': 'R', 'NSW': 'B'}
# {'T': ['R', 'G', 'B'], 'V': ['R']}
# {'WA': 'R', 'NT': 'B', 'SA': 'G', 'Q': 'R', 'NSW': 'B', 'V': 'R'}
# {'T': ['R', 'G', 'B']}
# {'WA': 'R', 'NT': 'B', 'SA': 'G', 'Q': 'R', 'NSW': 'B', 'V': 'R', 'T': 'G'}

# %% [markdown]
# **Select node randomly**

# %%
def get_RandomNode(rv):
    remaining_nodes = [k for k in rv.keys()]
    node = random.choice(remaining_nodes)
    return node

# %%
assigned = {}

remainingValues = {'WA': ['R','G','B'], 
                    'Q': ['R','G','B'],
                    'T': ['R','G','B'],
                    'V':  ['R','G','B'], 
                    'NT': ['R','G','B'],
                    'SA': ['R','G','B'],                    
                    'NSW': ['R','G','B']}

for i in range(len(cgraph)):
    # assign color to the highest degree node
    print(remainingValues)
    rndNode = get_RandomNode(remainingValues)
    print('Selected Node: '+rndNode)
    color = get_color(rndNode, remainingValues, cgraph)
    # CODE
    # check if 'no color' is returned
    # print failure
    if color == "no color":
      print("FAILURE")
      break

    assigned[rndNode]= color    
    print(assigned)
# Out:
# {'WA': ['R', 'G', 'B'], 'Q': ['R', 'G', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'NT': ['R', 'G', 'B'], 'SA': ['R', 'G', 'B'], 'NSW': ['R', 'G', 'B']}
# Selected Node: NT
# {'NT': 'G'}
# {'WA': ['R', 'B'], 'Q': ['R', 'B'], 'T': ['R', 'G', 'B'], 'V': ['R', 'G', 'B'], 'SA': ['R', 'B'], 'NSW': ['R', 'G', 'B']}
# Selected Node: T
# {'NT': 'G', 'T': 'R'}
# {'WA': ['R', 'B'], 'Q': ['R', 'B'], 'V': ['R', 'G', 'B'], 'SA': ['R', 'B'], 'NSW': ['R', 'G', 'B']}
# Selected Node: SA
# {'NT': 'G', 'T': 'R', 'SA': 'B'}
# {'WA': ['R'], 'Q': ['R'], 'V': ['R', 'G'], 'NSW': ['R', 'G']}
# Selected Node: V
# {'NT': 'G', 'T': 'R', 'SA': 'B', 'V': 'R'}
# {'WA': ['R'], 'Q': ['R'], 'NSW': ['G']}
# Selected Node: WA
# {'NT': 'G', 'T': 'R', 'SA': 'B', 'V': 'R', 'WA': 'R'}
# {'Q': ['R'], 'NSW': ['G']}
# Selected Node: Q
# {'NT': 'G', 'T': 'R', 'SA': 'B', 'V': 'R', 'WA': 'R', 'Q': 'R'}
# {'NSW': ['G']}
# Selected Node: NSW
# {'NT': 'G', 'T': 'R', 'SA': 'B', 'V': 'R', 'WA': 'R', 'Q': 'R', 'NSW': 'G'}
